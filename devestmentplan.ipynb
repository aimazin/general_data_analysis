# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
19340/12
# Out:
# 1611.6666666666667

# %%
advance=1600 #salary advance
income=1611#base income

# %%
m=[]#linear break even of 10 percent of salary
for i in range(0,12):
    if m ==[]:
        t=advance-.1*income
        m.append(t)
    else:
        tm=m[-1]-.1*income
        m.append(tm)

# %%
m.reverse()

# %%
b=pd.DataFrame([np.ones(12)*advance, np.array(m).T-np.min(m)]).T
b.columns=['breakeven','company_gain']

# %%
sns.lineplot(data=b)
plt.title('Time I plan to Break Even on Advance on Salary')
plt.xlabel('months')
plt.ylabel('amount in £')
# Out:
# Text(0, 0.5, 'amount in £')
